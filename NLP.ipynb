# %%
sentence = "NLP is one of the most important fields in AI!"
# remove stop words and punctuation
def remove_stopwords(sent):
    # remove stopwords
    stop_words = {'is','and','the','a','of','to','in','am','are','an'}
    new_sent = " ".join([word for word in sent.split() if word.lower() not in stop_words])
    # remove punctuations
    import re
    new_sent = re.sub(r'[^\w\s]',"",new_sent)
    return new_sent
remove_stopwords(sentence)
# Out:
# 'NLP one most important fields AI'

# %%
data = f"Hello \n hi"
print(data)
# Out:
# Hello
#  hi

# %%
a,b = 9,9
if a^b:
    print("not equal to ")
else:
    print("equal to ")
# Out:
# equal to

# %%
# Grouping Anagrams from a list
# iterate over the list
# sort the word
# store the sorted word in a set
# check if the sorted word is present in the set then group it in a list
lst = ["eat","tea","tan","ate","nat","bat"]
def group_anagram(lst):
    set_check = {}
    for word in lst:
        sorted_word = "".join(sorted(word))
        if sorted_word not in set_check:
            set_check[sorted_word] = []
        set_check[sorted_word].append(word)
    return list(set_check.values())
group_anagram(lst)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
