# %%
sentence = "NLP is one of the most important fields in AI!"
# remove stop words and punctuation
def remove_stopwords(sent):
    # remove stopwords
    stop_words = {'is','and','the','a','of','to','in','am','are','an'}
    new_sent = " ".join([word for word in sent.split() if word.lower() not in stop_words])
    # remove punctuations
    import re
    new_sent = re.sub(r'[^\w\s]',"",new_sent)
    return new_sent
remove_stopwords(sentence)
# Out:
# 'NLP one most important fields AI'

# %%
data = f"Hello \n hi"
data
# Out:
# 'Hello \n hi'

# %%
a,b = 9,9
if a^b:
    print("not equal to ")
else:
    print("equal to ")
# Out:
# equal to

# %%
# Grouping Anagrams from a list
# iterate over the list
# sort the word
# store the sorted word in a set
# check if the sorted word is present in the set then group it in a list
lst = ["eat","tea","tan","ate","nat","bat"]
def group_anagram(lst):
    set_check = {}
    for word in lst:
        sorted_word = "".join(sorted(word))
        if sorted_word not in set_check:
            set_check[sorted_word] = []
        set_check[sorted_word].append(word)
    return list(set_check.values())
group_anagram(lst)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
# print word counts in decendin order
import re
input_text = '''The rain had been falling since dawn, a steady rain that whispered against the rooftops and painted the streets silver. Mira stepped outside, letting the rain cool her warm skin as the world blurred behind a curtain of rain. She didn’t mind the rain—in fact, she loved how the rain washed away the noise of the city, leaving only the soft rhythm of droplets. Every worry felt lighter in the rain, every thought clearer, as if the rain itself carried a quiet kind of magic. simillar to this'''
input_text = re.sub(r"[^\w\s]","",input_text.lower())
print(input_text)
word_list = input_text.split()
key_dict = {}
for word in word_list:
    if word not in key_dict:
        key_dict[word] = 1
    else:
        key_dict[word] += 1
value_sorted = sorted(set(key_dict.values()),reverse=True)
for val in value_sorted:
    for key, value in key_dict.items():
        if value == val:
            print(key, val)
# Out:
# the rain had been falling since dawn a steady rain that whispered against the rooftops and painted the streets silver mira stepped outside letting the rain cool her warm skin as the world blurred behind a curtain of rain she didnt mind the rainin fact she loved how the rain washed away the noise of the city leaving only the soft rhythm of droplets every worry felt lighter in the rain every thought clearer as if the rain itself carried a quiet kind of magic simillar to this
# the 12
# rain 7
# of 4
# a 3
# as 2
# she 2
# every 2
# had 1
# been 1
# falling 1
# since 1
# dawn 1
# steady 1
# that 1
# whispered 1
# against 1
# rooftops 1
# and 1
# painted 1
# streets 1
# silver 1
# mira 1
# stepped 1
# outside 1
# letting 1
# cool 1
# her 1
# warm 1
# skin 1
# world 1
# blurred 1
# behind 1
# curtain 1
# didnt 1
# mind 1
# rainin 1
# fact 1
# loved 1
# how 1
# washed 1
# away 1
# noise 1
# city 1
# leaving 1
# only 1
# soft 1
# rhythm 1
# droplets 1
# worry 1
# felt 1
# lighter 1
# in 1
# ...

# %%
5//2
# Out:
# 2
